# %%
import keras
from keras.layers import StringLookup
from keras import ops
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import os

# %%
np.random.seed(42)
keras.utils.set_random_seed(42)

# %%
base_path = "data"
words_list = []

words = open(f"{base_path}/words.txt", "r").readlines()
for line in words:
    if line[0] == "#":
        continue
    if line.split(" ")[1] != "err":  # We don't need to deal with errored entries.
        words_list.append(line)

len(words_list)

np.random.shuffle(words_list)

split_idx = int(0.9 * len(words_list))
train_samples = words_list[:split_idx]
test_samples = words_list[split_idx:]

val_split_idx = int(0.5 * len(test_samples))
validation_samples = test_samples[:val_split_idx]
test_samples = test_samples[val_split_idx:]

assert len(words_list) == len(train_samples) + len(validation_samples) + len(
    test_samples
)

print(f"Total training samples: {len(train_samples)}")
print(f"Total validation samples: {len(validation_samples)}")
print(f"Total test samples: {len(test_samples)}")
# Out:
# Total training samples: 86810
# Total validation samples: 4823
# Total test samples: 4823

# %%
base_image_path = os.path.join(base_path, "words")


def get_image_paths_and_labels(samples):
    paths = []
    corrected_samples = []
    for i, file_line in enumerate(samples):
        line_split = file_line.strip()
        line_split = line_split.split(" ")

        # Each line split will have this format for the corresponding image:
        # part1/part1-part2/part1-part2-part3.png
        image_name = line_split[0]
        partI = image_name.split("-")[0]
        partII = image_name.split("-")[1]
        img_path = os.path.join(
            base_image_path, partI, partI + "-" + partII, image_name + ".png"
        )
        if os.path.getsize(img_path):
            paths.append(img_path)
            corrected_samples.append(file_line.split("\n")[0])

    return paths, corrected_samples


train_img_paths, train_labels = get_image_paths_and_labels(train_samples)
validation_img_paths, validation_labels = get_image_paths_and_labels(validation_samples)
test_img_paths, test_labels = get_image_paths_and_labels(test_samples)

# %%
# Find maximum length and the size of the vocabulary in the training data.
train_labels_cleaned = []
characters = set()
max_len = 0

for label in train_labels:
    label = label.split(" ")[-1].strip()
    for char in label:
        characters.add(char)

    max_len = max(max_len, len(label))
    train_labels_cleaned.append(label)

characters = sorted(list(characters))

print("Maximum length: ", max_len)
print("Vocab size: ", len(characters))
# Out:
# Maximum length:  21
# Vocab size:  78

# %%
# Check some label samples.
train_labels_cleaned[:10]

def clean_labels(labels):
    cleaned_labels = []
    for label in labels:
        label = label.split(" ")[-1].strip()
        cleaned_labels.append(label)
    return cleaned_labels


validation_labels_cleaned = clean_labels(validation_labels)
test_labels_cleaned = clean_labels(test_labels)

AUTOTUNE = tf.data.AUTOTUNE

# %%
# Mapping characters to integers.
char_to_num = StringLookup(vocabulary=list(characters), mask_token=None)

# Mapping integers back to original characters.
num_to_char = StringLookup(
    vocabulary=char_to_num.get_vocabulary(), mask_token=None, invert=True
)

def distortion_free_resize(image, img_size):
    w, h = img_size
    image = tf.image.resize(image, size=(h, w), preserve_aspect_ratio=True)

    # Check tha amount of padding needed to be done.
    pad_height = h - ops.shape(image)[0]
    pad_width = w - ops.shape(image)[1]

    # Only necessary if you want to do same amount of padding on both sides.
    if pad_height % 2 != 0:
        height = pad_height // 2
        pad_height_top = height + 1
        pad_height_bottom = height
    else:
        pad_height_top = pad_height_bottom = pad_height // 2

    if pad_width % 2 != 0:
        width = pad_width // 2
        pad_width_left = width + 1
        pad_width_right = width
    else:
        pad_width_left = pad_width_right = pad_width // 2

    image = tf.pad(
        image,
        paddings=[
            [pad_height_top, pad_height_bottom],
            [pad_width_left, pad_width_right],
            [0, 0],
        ],
    )

    image = ops.transpose(image, (1, 0, 2))
    image = tf.image.flip_left_right(image)
    return image

# %%
batch_size = 64
padding_token = 99
image_width = 128
image_height = 32


def preprocess_image(image_path, img_size=(image_width, image_height)):
    image = tf.io.read_file(image_path)
    image = tf.image.decode_png(image, 1)
    image = distortion_free_resize(image, img_size)
    image = ops.cast(image, tf.float32) / 255.0
    return image


def vectorize_label(label):
    label = char_to_num(tf.strings.unicode_split(label, input_encoding="UTF-8"))
    length = ops.shape(label)[0]
    pad_amount = max_len - length
    label = tf.pad(label, paddings=[[0, pad_amount]], constant_values=padding_token)
    return label


def process_images_labels(image_path, label):
    image = preprocess_image(image_path)
    label = vectorize_label(label)
    return {"image": image, "label": label}


def prepare_dataset(image_paths, labels):
    dataset = tf.data.Dataset.from_tensor_slices((image_paths, labels)).map(
        process_images_labels, num_parallel_calls=AUTOTUNE
    )
    return dataset.batch(batch_size).cache().prefetch(AUTOTUNE)

# %%
train_ds = prepare_dataset(train_img_paths, train_labels_cleaned)
validation_ds = prepare_dataset(validation_img_paths, validation_labels_cleaned)
test_ds = prepare_dataset(test_img_paths, test_labels_cleaned)

for data in train_ds.take(1):
    images, labels = data["image"], data["label"]

    _, ax = plt.subplots(4, 4, figsize=(15, 8))

    for i in range(16):
        img = images[i]
        img = tf.image.flip_left_right(img)
        img = ops.transpose(img, (1, 0, 2))
        img = (img * 255.0).numpy().clip(0, 255).astype(np.uint8)
        img = img[:, :, 0]

        # Gather indices where label!= padding_token.
        label = labels[i]
        indices = tf.gather(label, tf.where(tf.math.not_equal(label, padding_token)))
        # Convert to string.
        label = tf.strings.reduce_join(num_to_char(indices))
        label = label.numpy().decode("utf-8")

        ax[i // 4, i % 4].imshow(img, cmap="gray")
        ax[i // 4, i % 4].set_title(label)
        ax[i // 4, i % 4].axis("off")


plt.show()

# %%
class CTCLayer(keras.layers.Layer):
    def __init__(self, name=None):
        super().__init__(name=name)
        self.loss_fn = tf.keras.backend.ctc_batch_cost

    def call(self, y_true, y_pred):
        batch_len = ops.cast(ops.shape(y_true)[0], dtype="int64")
        input_length = ops.cast(ops.shape(y_pred)[1], dtype="int64")
        label_length = ops.cast(ops.shape(y_true)[1], dtype="int64")

        input_length = input_length * ops.ones(shape=(batch_len, 1), dtype="int64")
        label_length = label_length * ops.ones(shape=(batch_len, 1), dtype="int64")
        loss = self.loss_fn(y_true, y_pred, input_length, label_length)
        self.add_loss(loss)

        # At test time, just return the computed predictions.
        return y_pred

# %%
def build_model():
    # Inputs to the model
    input_img = keras.Input(shape=(image_width, image_height, 1), name="image")
    labels = keras.layers.Input(name="label", shape=(None,))

    # First conv block.
    x = keras.layers.Conv2D(
        32,
        (3, 3),
        activation="relu",
        kernel_initializer="he_normal",
        padding="same",
        name="Conv1",
    )(input_img)
    x = keras.layers.MaxPooling2D((2, 2), name="pool1")(x)

    # Second conv block.
    x = keras.layers.Conv2D(
        64,
        (3, 3),
        activation="relu",
        kernel_initializer="he_normal",
        padding="same",
        name="Conv2",
    )(x)
    x = keras.layers.MaxPooling2D((2, 2), name="pool2")(x)

    # We have used two max pool with pool size and strides 2.
    # Hence, downsampled feature maps are 4x smaller. The number of
    # filters in the last layer is 64. Reshape accordingly before
    # passing the output to the RNN part of the model.
    new_shape = ((image_width // 4), (image_height // 4) * 64)
    x = keras.layers.Reshape(target_shape=new_shape, name="reshape")(x)
    x = keras.layers.Dense(64, activation="relu", name="dense1")(x)
    x = keras.layers.Dropout(0.2)(x)

    # RNNs.
    x = keras.layers.Bidirectional(
        keras.layers.LSTM(128, return_sequences=True, dropout=0.25)
    )(x)
    x = keras.layers.Bidirectional(
        keras.layers.LSTM(64, return_sequences=True, dropout=0.25)
    )(x)

    # +2 is to account for the two special tokens introduced by the CTC loss.
    # The recommendation comes here: https://git.io/J0eXP.
    x = keras.layers.Dense(
        len(char_to_num.get_vocabulary()) + 2, activation="softmax", name="dense2"
    )(x)

    # Add CTC layer for calculating CTC loss at each step.
    output = CTCLayer(name="ctc_loss")(labels, x)

    # Define the model.
    model = keras.models.Model(
        inputs=[input_img, labels], outputs=output, name="handwriting_recognizer"
    )
    # Optimizer.
    opt = keras.optimizers.Adam()
    # Compile the model and return.
    model.compile(optimizer=opt)
    return model


# Get the model.
model = build_model()
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\ADMIN\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\core.py:204: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\ADMIN\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\legacy\backend.py:666: The name tf.nn.ctc_loss is deprecated. Please use tf.compat.v1.nn.ctc_loss instead.
# Model: "handwriting_recognizer"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ image (InputLayer)            │ (None, 128, 32, 1)        │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Conv1 (Conv2D)                │ (None, 128, 32, 32)       │             320 │ image[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ pool1 (MaxPooling2D)          │ (None, 64, 16, 32)        │               0 │ Conv1[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Conv2 (Conv2D)                │ (None, 64, 16, 64)        │          18,496 │ pool1[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ pool2 (MaxPooling2D)          │ (None, 32, 8, 64)         │               0 │ Conv2[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ reshape (Reshape)             │ (None, 32, 512)           │               0 │ pool2[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense1 (Dense)                │ (None, 32, 64)            │          32,832 │ reshape[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout (Dropout)             │ (None, 32, 64)            │               0 │ dense1[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ bidirectional (Bidirectional) │ (None, 32, 256)           │         197,632 │ dropout[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ bidirectional_1               │ (None, 32, 128)           │         164,352 │ bidirectional[0][0]        │
# │ (Bidirectional)               │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ label (InputLayer)            │ (None, None)              │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense2 (Dense)                │ (None, 32, 81)            │          10,449 │ bidirectional_1[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ ctc_loss (CTCLayer)           │ (None, 32, 81)            │               0 │ label[0][0], dense2[0][0]  │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 424,081 (1.62 MB)
#  Trainable params: 424,081 (1.62 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
validation_images = []
validation_labels = []

for batch in validation_ds:
    validation_images.append(batch["image"])
    validation_labels.append(batch["label"])

def calculate_edit_distance(labels, predictions):
    # Get a single batch and convert its labels to sparse tensors.
    saprse_labels = ops.cast(tf.sparse.from_dense(labels), dtype=tf.int64)

    # Make predictions and convert them to sparse tensors.
    input_len = np.ones(predictions.shape[0]) * predictions.shape[1]
    predictions_decoded = keras.ops.nn.ctc_decode(
        predictions, sequence_lengths=input_len
    )[0][0][:, :max_len]
    sparse_predictions = ops.cast(
        tf.sparse.from_dense(predictions_decoded), dtype=tf.int64
    )

    # Compute individual edit distances and average them out.
    edit_distances = tf.edit_distance(
        sparse_predictions, saprse_labels, normalize=False
    )
    return tf.reduce_mean(edit_distances)


class EditDistanceCallback(keras.callbacks.Callback):
    def __init__(self, pred_model):
        super().__init__()
        self.prediction_model = pred_model

    def on_epoch_end(self, epoch, logs=None):
        edit_distances = []

        for i in range(len(validation_images)):
            labels = validation_labels[i]
            predictions = self.prediction_model.predict(validation_images[i])
            edit_distances.append(calculate_edit_distance(labels, predictions).numpy())

        print(
            f"Mean edit distance for epoch {epoch + 1}: {np.mean(edit_distances):.4f}"
        )

epochs = 10  # To get good results this should be at least 50.

model = build_model()
prediction_model = keras.models.Model(
    model.get_layer(name="image").output, model.get_layer(name="dense2").output
)
edit_distance_callback = EditDistanceCallback(prediction_model)

# Train the model.
history = model.fit(
    train_ds,
    validation_data=validation_ds,
    epochs=epochs,
    callbacks=[edit_distance_callback],
)

def decode_batch_predictions(pred):
    input_len = np.ones(pred.shape[0]) * pred.shape[1]
    # Use greedy search. For complex tasks, you can use beam search.
    results = keras.ops.nn.ctc_decode(pred, sequence_lengths=input_len)[0][0][
        :, :max_len
    ]
    # Iterate over the results and get back the text.
    output_text = []
    for res in results:
        res = tf.gather(res, tf.where(tf.math.not_equal(res, -1)))
        res = (
            tf.strings.reduce_join(num_to_char(res))
            .numpy()
            .decode("utf-8")
            .replace("[UNK]", "")
        )
        output_text.append(res)
    return output_text

for batch in test_ds.take(1):
    batch_images = batch["image"]
    _, ax = plt.subplots(4, 4, figsize=(15, 8))

    preds = prediction_model.predict(batch_images)
    pred_texts = decode_batch_predictions(preds)

    for i in range(16):
        img = batch_images[i]
        img = tf.image.flip_left_right(img)
        img = ops.transpose(img, (1, 0, 2))
        img = (img * 255.0).numpy().clip(0, 255).astype(np.uint8)
        img = img[:, :, 0]

        title = f"Prediction: {pred_texts[i]}"
        ax[i // 4, i % 4].imshow(img, cmap="gray")
        ax[i // 4, i % 4].set_title(title)
        ax[i // 4, i % 4].axis("off")

plt.show()
# Out:
# Epoch 1/10
# C:\Users\ADMIN\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['image', 'label']. Received: the structure of inputs={'image': '*', 'label': '*'}
#   warnings.warn(
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step s/step - loss: 1069.23
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 909ms/step
# Mean edit distance for epoch 1: 20.4443
# 1357/1357 ━━━━━━━━━━━━━━━━━━━━ 225s 159ms/step - loss: 1068.9480 - val_loss: 769.1436
# Epoch 2/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/steps/step - loss: 735.827
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Mean edit distance for epoch 2: 20.1612
# 1357/1357 ━━━━━━━━━━━━━━━━━━━━ 121s 89ms/step - loss: 735.7815 - val_loss: 634.9090
# Epoch 3/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/steps/step - loss: 622.956
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Mean edit distance for epoch 3: 19.8977
# 1357/1357 ━━━━━━━━━━━━━━━━━━━━ 118s 87ms/step - loss: 622.9272 - val_loss: 537.1884
# Epoch 4/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/steps/step - loss: 542.703
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Mean edit distance for epoch 4: 19.7640
# 1357/1357 ━━━━━━━━━━━━━━━━━━━━ 123s 91ms/step - loss: 542.6721 - val_loss: 436.9944
# Epoch 5/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/steps/step - loss: 454.83
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Mean edit distance for epoch 5: 19.8182
# 1357/1357 ━━━━━━━━━━━━━━━━━━━━ 125s 92ms/step - loss: 454.8013 - val_loss: 344.8180
# Epoch 6/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/steps/step - loss: 377.045
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Mean edit distance for epoch 6: 19.7831
# 1357/1357 ━━━━━━━━━━━━━━━━━━━━ 123s 90ms/step - loss: 377.0251 - val_loss: 288.7545
# Epoch 7/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/steps/step - loss: 326.681
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Mean edit distance for epoch 7: 19.7634
# 1357/1357 ━━━━━━━━━━━━━━━━━━━━ 125s 92ms/step - loss: 326.6742 - val_loss: 255.5505
# Epoch 8/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/steps/step - loss: 291.312
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Mean edit distance for epoch 8: 19.7544
# 1357/1357 ━━━━━━━━━━━━━━━━━━━━ 129s 95ms/step - loss: 291.3018 - val_loss: 225.8080
# Epoch 9/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/steps/step - loss: 266.023
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Mean edit distance for epoch 9: 19.7538
# 1357/1357 ━━━━━━━━━━━━━━━━━━━━ 128s 95ms/step - loss: 266.0153 - val_loss: 205.2085
# Epoch 10/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/steps/step - loss: 246.008
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Mean edit distance for epoch 10: 19.7436
# 1357/1357 ━━━━━━━━━━━━━━━━━━━━ 128s 95ms/step - loss: 246.0033 - val_loss: 189.8382
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
